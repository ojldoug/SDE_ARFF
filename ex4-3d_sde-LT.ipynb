# %%
import numpy as np
import os
import ipynbname
script_dir = os.getcwd()
filename = ipynbname.name()

from sde.SDE_ARFF_lib import (
    SDEARFFTrain,
    NNHyperparameters
)

from sde.experiment_reports_owen import (
    PlotResults,
    sample_data,
    mean_min_loss,
)

# %load_ext autoreload
# %autoreload 2

# %%
# notebook parameters
n_dimensions = 3
step_size = .25
n_pts = 20000
n_subsample = 10

random_seed = 1
rng = np.random.default_rng(random_seed)

# %%
# EXAMPLE 2
def f_1(x):
    A = 0
    B = np.array([[-1], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    f = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return f


def f_2(x):
    A = 0
    B = np.array([[0], [-1], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    f = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return f


def f_3(x):
    A = 0
    B = np.array([[0], [0], [-1]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    f = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return f


def true_drift(x):
    drift = np.transpose(np.array([f_1(x), f_2(x), f_3(x)]))
    return drift


def sigma_11(x):
    A = 0.09506174
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_12(x):
    A = 0.04639143
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_13(x):
    A = 0.04337843
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_22(x):
    A = 0.15817465
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_23(x):
    A = 0.07506578
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_33(x):
    A = 0.00852886
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def sigma_21(x):
    A = 0
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def sigma_31(x):
    A = 0
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def sigma_32(x):
    A = 0
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def true_diffusion(x):
    diffusion = np.abs(np.transpose(np.array([[sigma_11(x), sigma_12(x), sigma_13(x)], [sigma_21(x), sigma_22(x), sigma_23(x)], [sigma_31(x), sigma_32(x), sigma_33(x)]])))
    return diffusion


def true_drift_diffusion(x, param=None):
    return true_drift(x), true_diffusion(x)


print(true_diffusion((0,0,0)))

rng = np.random.default_rng(random_seed)

xlim = np.array([[-1, 1], [-1, 1], [-1, 1]])

x_data, y_data, _ = sample_data(true_drift_diffusion, step_size,
                                n_pts, n_subsample, rng, xlim)

step_sizes = np.zeros((x_data.shape[0],)) + step_size

print('data shape', x_data.shape)
# Out:
# [[0.09506174 0.         0.        ]
#  [0.04639143 0.15817465 0.        ]
#  [0.04337843 0.07506578 0.00852886]]
# data shape (20000, 3)

# %%
# network parameters
validation_split = .1
ARFF_validation_split = .1

drift_param = NNHyperparameters(K=2**7, 
                                M_min=10,
                                M_max=500,
                                lambda_reg=2e-3,
                                gamma=1,
                                delta=0.1,
                                name='drift')
diff_param = NNHyperparameters(K=drift_param.K,
                               M_min=drift_param.M_min,
                               M_max=drift_param.M_max,
                               lambda_reg=drift_param.lambda_reg,
                               gamma=drift_param.gamma,
                               delta=drift_param.delta,
                               name='diff')

# %%
# calculate theoretical mean min loss (integral over loss function)
mean_min_loss(true_diffusion, n_pts, validation_split, step_size, xlim)
# Out:
# Theoretical mean min loss: -6.784209694856813
# Loss standard deviation: 0.009128709291752768
# Validation loss standard deviation: 0.027386127875258306

# %%
No_of_tests = 1
training_time = np.zeros(No_of_tests)
val_loss = np.zeros(No_of_tests)

for i in range(No_of_tests):
    SAT = SDEARFFTrain(n_dimensions=n_dimensions, diff_type="triangular", constant_diff=False, resampling=True)
    hist = SAT.train_model(drift_param, diff_param, true_drift, true_diffusion, x_data, y_data, step_sizes=step_sizes, validation_split=validation_split, ARFF_validation_split=ARFF_validation_split, plot=True)
    training_time[i] = hist.history["training_time"]
    val_loss[i] = hist.history["val_loss"]
# Out:
# drift epoch: 16
# diff epoch: 10
# Observed loss: -7.087946733036181
# Observed validation loss: -7.057125004689102
# True function validation loss: 1.182835343999686
# Training time: 3.217319965362549

# %%
# display and save plots
PR = PlotResults(script_dir=script_dir, filename=filename, n_subsample=n_subsample)

if No_of_tests > 1:
    PR.loss_stats(training_time, val_loss, save=False)

PR.plot_results_functions(SAT.drift_diffusion, true_drift_diffusion, x_data, save=False)

time = 10*step_size
PR.plot_histogram(true_drift_diffusion, step_size/n_subsample, time, rng, xlim, name='True', save=False)
PR.plot_histogram(SAT.drift_diffusion, step_size, time, rng, xlim, name='ARFF', save=False)
# Out:
# figures_per_row 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       9 time = 100*step_size
#      10 PR.plot_histogram(true_drift_diffusion, step_size/n_subsample, time, rng, xlim, name='True', save=False)
# ---> 11 PR.plot_histogram(SAT.drift_diffusion, step_size, time, rng, xlim, name='ARFF', save=False)
#
# File ~\Documents\work\kaust\work\ARFF SDE project\code\CPU code\sde\experiment_reports_owen.py:357, in PlotResults.plot_histogram(self, drift_diffusion, step_size, time, rng, ylim, plim, coupled_func, sim_No, name, save)
#     356 def plot_histogram(self, drift_diffusion, step_size, time, rng, ylim, plim=None, coupled_func=None, sim_No=10000, name=None, save=False):
# --> 357     X = PlotResults.histogram_data(drift_diffusion, step_size, time, rng, ylim, plim, coupled_func, sim_No)
#     359     if plim is None:
#     360         xlim = ylim
#
# File ~\Documents\work\kaust\work\ARFF SDE project\code\CPU code\sde\experiment_reports_owen.py:335, in PlotResults.histogram_data(drift_diffusion, step_size, time, rng, ylim, plim, coupled_func, sim_No)
#     333 # get euler-maruyama components
#     334 dW = rng.normal(loc=0, scale=np.sqrt(step_size), size=(len(active_indices), ylim.shape[0]))
# --> 335 drift_, diff_ = drift_diffusion(X_active)
#     336 drift_ = drift_.reshape(-1, ylim.shape[0])
#     337 diff_ = diff_.reshape(-1, ylim.shape[0], ylim.shape[0])
#
# File ~\Documents\work\kaust\work\ARFF SDE project\code\CPU code\sde\SDE_ARFF_lib.py:125, in SDEARFFTrain.drift_diffusion(self, x)
#     124 def drift_diffusion(self, x):
# --> 125     return SDEARFFTrain.drift(self, x), SDEARFFTrain.diff(self, x)
#
# File ~\Documents\work\kaust\work\ARFF SDE project\code\CPU code\sde\SDE_ARFF_lib.py:112, in SDEARFFTrain.diff(self, x)
#     110 if self.diff_type == "triangular":
#     111     with Pool() as pool:
# --> 112         diff_matrix = np.array(pool.map(SDEARFFTrain.matrix_cholesky, diff_matrix))
#     113 else:
#     114     with Pool() as pool:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
rng = np.random.default_rng(random_seed)

ax = plot_results_functions(SAT.drift_diffusion, true_drift_diffusion,
                            x_data, y_data, rng,
                            data_transform_network=None,
                            data_transform_true=None)

# output_dir = os.path.join(script_dir, 'trained_vs_true_plots')
# output_path = os.path.join(output_dir, f"{filename}")
# plt.savefig(output_path, dpi=300, bbox_inches='tight')
# Out:
# figures_per_row 3

# %%
time = 10*step_size
true_paths = histogram_data(true_drift_diffusion, xlim, step_size, time, n_dimensions, random_seed)
ARFF_paths = histogram_data(SAT.drift_diffusion, xlim, step_size, time, n_dimensions, random_seed)

plot_histogram(true_paths, xlim, step_size)
plot_histogram(ARFF_paths, xlim, step_size)

# output_dir = os.path.join(script_dir, 'histogram_data')

# output_path_true = os.path.join(output_dir, f"{filename}_data.txt")
# with open(output_path_true, 'w') as file:
#     file.write(f"{step_size},{xlim}\n")

# output_path_true = os.path.join(output_dir, f"{filename}_true.npy")
# np.save(output_path_true, true_paths)

# output_path_ARFF = os.path.join(output_dir, f"{filename}_ARFF.npy")
# np.save(output_path_ARFF, ARFF_paths)
