# %%
import numpy as np
import os
import ipynbname
script_dir = os.getcwd()
filename = ipynbname.name()

from sde.SDE_ARFF_lib import (
    SDEARFFTrain,
    NNHyperparameters
)

from sde.experiment_reports_owen import (
    PlotResults,
    sample_data
)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# notebook parameters
n_dimensions = 3
step_size = 1e-2
n_pts = 10000
n_subsample = 1000

random_seed = 1

# %%
# network parameters
validation_split = .1
ARFF_validation_split = .1

drift_param = NNHyperparameters(K=2**7, 
                                M_min=10,
                                M_max=500,
                                lambda_reg=2e-3,
                                gamma=1,
                                delta=0.1,
                                name='drift')
diff_param = NNHyperparameters(K=drift_param.K,
                               M_min=drift_param.M_min,
                               M_max=drift_param.M_max,
                               lambda_reg=drift_param.lambda_reg,
                               gamma=drift_param.gamma,
                               delta=drift_param.delta,
                               name='diff')

# %%
# EXAMPLE 2
def f_1(x):
    A = 0
    B = np.array([[-1], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    f = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return f


def f_2(x):
    A = 0
    B = np.array([[0], [-1], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    f = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return f


def f_3(x):
    A = 0
    B = np.array([[0], [0], [-1]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    f = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return f


def true_drift(x):
    drift = np.transpose(np.array([f_1(x), f_2(x), f_3(x)]))
    return drift


def sigma_11(x):
    A = 0.09506174
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_12(x):
    A = 0.04639143
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_13(x):
    A = 0.04337843
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_22(x):
    A = 0.15817465
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_23(x):
    A = 0.07506578
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma


def sigma_33(x):
    A = 0.00852886
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def sigma_21(x):
    A = 0
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def sigma_31(x):
    A = 0
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def sigma_32(x):
    A = 0
    B = np.array([[0], [0], [0]])
    C = np.array([[0], [0], [0]])
    D = np.array([[0], [0], [0]])
    sigma = np.squeeze(A + np.dot(x, B) + np.dot(np.square(x), C) + np.dot(np.power(x, 3), D))
    return sigma

def true_diffusion(x):
    diffusion = np.abs(np.transpose(np.array([[sigma_11(x), sigma_12(x), sigma_13(x)], [sigma_21(x), sigma_22(x), sigma_23(x)], [sigma_31(x), sigma_32(x), sigma_33(x)]])))
    return diffusion


def true_drift_diffusion(x):
    return true_drift(x), true_diffusion(x)


print(true_diffusion((0,0,0)))

xlim = np.array([[-1, 1], [-1, 1], [-1, 1]])

step_sizes = np.zeros((n_pts, 1)) + step_size
# Out:
# [[0.09506174 0.         0.        ]
#  [0.04639143 0.15817465 0.        ]
#  [0.04337843 0.07506578 0.00852886]]

# %%
# train networks
No_of_tests = 10
training_time = np.zeros(No_of_tests)
val_loss = np.zeros(No_of_tests)

for i in range(No_of_tests):
    rng = np.random.default_rng(random_seed + i)

    # generate data
    x_data, y_data, _ = sample_data(true_drift_diffusion, step_size, n_pts, n_subsample, rng, xlim)

    # build network
    SAT = SDEARFFTrain(n_dimensions=n_dimensions, diff_type="triangular", rng=rng, resampling=True)

    # train network
    hist = SAT.train_model(drift_param, diff_param, true_drift, true_diffusion, x_data, y_data, step_sizes=step_sizes, validation_split=validation_split, ARFF_validation_split=ARFF_validation_split, plot=False)
    
    training_time[i] = hist.history["training_time"]
    val_loss[i] = hist.history["val_loss"]
# Out:
# drift epoch: 11
# diff epoch: 21
# Drift RMSE: 0.02788682592067296
# Diffusion RMSE: 0.003442296879249526
# Observed loss: -11.647425819159597
# Observed validation loss: -11.596071471266084
# True loss: -11.598638612355051
# Training time: 7.095322370529175
# drift epoch: 27
# diff epoch: 10
# Drift RMSE: 0.030029622815244163
# Diffusion RMSE: 0.001985295172495396
# Observed loss: -11.636645910112051
# Observed validation loss: -11.653472842883552
# True loss: -11.658510756336081
# Training time: 5.938080072402954
# drift epoch: 15
# diff epoch: 10
# Drift RMSE: 0.022404056963203828
# Diffusion RMSE: 0.0011532463054192573
# Observed loss: -11.614229683532855
# Observed validation loss: -11.617275865582798
# True loss: -11.622358810570717
# Training time: 3.198265790939331
# drift epoch: 10
# diff epoch: 10
# Drift RMSE: 0.02732630138207238
# Diffusion RMSE: 0.00199649004774114
# Observed loss: -11.607823093999297
# Observed validation loss: -11.643490553508435
# True loss: -11.650143181664758
# Training time: 1.839322566986084
# drift epoch: 13
# diff epoch: 10
# Drift RMSE: 0.0343799332482892
# Diffusion RMSE: 0.0013839660429799936
# Observed loss: -11.618392921129637
# Observed validation loss: -11.629833254966686
# True loss: -11.632014413222066
# Training time: 2.1265411376953125
# drift epoch: 10
# diff epoch: 21
# Drift RMSE: 0.026487751532067286
# Diffusion RMSE: 0.0023492140143849057
# Observed loss: -11.63246697300095
# Observed validation loss: -11.631500566129807
# True loss: -11.657077084198285
# Training time: 5.210500955581665
# drift epoch: 10
# diff epoch: 10
# Drift RMSE: 0.043677047105412384
# Diffusion RMSE: 0.001589318586742966
# Observed loss: -11.645391737070378
# Observed validation loss: -11.623780102103503
# True loss: -11.638174980348248
# Training time: 0.8713748455047607
# drift epoch: 11
# diff epoch: 10
# Drift RMSE: 0.036342396350223516
# Diffusion RMSE: 0.0015031146839301008
# Observed loss: -11.622120277256624
# Observed validation loss: -11.580241054451879
# True loss: -11.57781517095808
# Training time: 2.1963584423065186
# drift epoch: 10
# diff epoch: 13
# Drift RMSE: 0.02463199420458908
# Diffusion RMSE: 0.001885778977548573
# Observed loss: -11.628063830959283
# Observed validation loss: -11.549796056554348
# True loss: -11.568686533069346
# Training time: 2.5454421043395996
# drift epoch: 10
# diff epoch: 10
# Drift RMSE: 0.02303293950410055
# Diffusion RMSE: 0.0014763137139647095
# Observed loss: -11.6127955993099
# Observed validation loss: -11.59581145066016
# True loss: -11.602884990471011
# Training time: 1.1256027221679688

# %%
# display and save plots
PR = PlotResults(script_dir=script_dir, filename=filename, n_subsample=n_subsample)

# calculate theoretical mean min loss (integral over loss function across input domain)
PR.mean_min_loss(true_diffusion, n_pts, validation_split, step_size, xlim, save=True)

if No_of_tests > 1:
    PR.loss_stats(training_time, val_loss, save=True)

PR.plot_results_functions(SAT.drift_diffusion, true_drift_diffusion, x_data, save=True)

time = 200*step_size
PR.plot_histogram(true_drift_diffusion, step_size, time, rng, xlim, name='True', save=True)
PR.plot_histogram(SAT.drift_diffusion, step_size, time, rng, xlim, name='ARFF', save=True)
# Out:
# Theoretical mean min loss: -11.612523432159097
# Loss standard deviation: 0.012909944487358056
# Validation loss standard deviation: 0.03872983346207417
# Mean Min Loss:  -11.612127321810725
# Mean Training Time:  3.214681100845337
# figures_per_row 3
